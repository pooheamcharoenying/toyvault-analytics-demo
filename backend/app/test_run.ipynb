# %%
import pandas as pd
import re

# %%
sale_data_file_name = "Sale Nichi Data To K.Pooh V.1.1 (20250915).xlsx"

match = re.search(r'\((.*?)\)', sale_data_file_name)
if match:
    result = match.group(1)
    file_date = result
    
df_raw_sale = pd.read_excel(sale_data_file_name, sheet_name='Sale')
df_raw_onhand = pd.read_excel(sale_data_file_name, sheet_name='OnHand')
df_item_master = pd.read_excel(sale_data_file_name, sheet_name='Item Master')
df_customer_master = pd.read_excel("CustomerMaster.xlsx")
